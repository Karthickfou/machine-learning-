# %%
import pandas as pd
import seaborn as sns

# %%
karthi=pd.read_excel('C:/Users/SRIDHAR/Documents//startup.xlsx')
karthi
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70             NaN        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5         NaN        99814.71        362861.36         NaN  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88             NaN        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
karthi.isnull().sum()
# Out:
# R&D Spend          4
# Administration     5
# Marketing Spend    5
# State              6
# Profit             0
# dtype: int64

# %%
karthi.style.highlight_null()
# Out:
# <style type="text/css">
# #T_e2de8_row1_col1, #T_e2de8_row5_col0, #T_e2de8_row5_col3, #T_e2de8_row9_col1, #T_e2de8_row15_col0, #T_e2de8_row15_col3, #T_e2de8_row18_col2, #T_e2de8_row23_col0, #T_e2de8_row26_col3, #T_e2de8_row30_col0, #T_e2de8_row31_col2, #T_e2de8_row32_col3, #T_e2de8_row37_col3, #T_e2de8_row39_col1, #T_e2de8_row39_col2, #T_e2de8_row40_col1, #T_e2de8_row40_col2, #T_e2de8_row43_col3, #T_e2de8_row47_col1, #T_e2de8_row47_col2 {
#   background-color: red;
# }
# </style>
# <table id="T_e2de8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e2de8_level0_col0" class="col_heading level0 col0" >R&D Spend</th>
#       <th id="T_e2de8_level0_col1" class="col_heading level0 col1" >Administration</th>
#       <th id="T_e2de8_level0_col2" class="col_heading level0 col2" >Marketing Spend</th>
#       <th id="T_e2de8_level0_col3" class="col_heading level0 col3" >State</th>
# ...

# %%
karthi.style.highlight_null(null_color='yellow')
# Out:
# <style type="text/css">
# #T_89fe3_row1_col1, #T_89fe3_row5_col0, #T_89fe3_row5_col3, #T_89fe3_row9_col1, #T_89fe3_row15_col0, #T_89fe3_row15_col3, #T_89fe3_row18_col2, #T_89fe3_row23_col0, #T_89fe3_row26_col3, #T_89fe3_row30_col0, #T_89fe3_row31_col2, #T_89fe3_row32_col3, #T_89fe3_row37_col3, #T_89fe3_row39_col1, #T_89fe3_row39_col2, #T_89fe3_row40_col1, #T_89fe3_row40_col2, #T_89fe3_row43_col3, #T_89fe3_row47_col1, #T_89fe3_row47_col2 {
#   background-color: yellow;
# }
# </style>
# <table id="T_89fe3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_89fe3_level0_col0" class="col_heading level0 col0" >R&D Spend</th>
#       <th id="T_89fe3_level0_col1" class="col_heading level0 col1" >Administration</th>
#       <th id="T_89fe3_level0_col2" class="col_heading level0 col2" >Marketing Spend</th>
#       <th id="T_89fe3_level0_col3" class="col_heading level0 col3" >State</th>
# ...

# %%
from sklearn.preprocessing import LabelEncoder
n=LabelEncoder()
karthi.iloc[:,3]=n.fit_transform(karthi.iloc[:,3])

# %%
print(karthi)
# Out:
#     R&D Spend  Administration  Marketing Spend  State     Profit
# 0   165349.20       136897.80        471784.10      2  192261.83
# 1   162597.70             NaN        443898.53      0  191792.06
# 2   153441.51       101145.55        407934.54      1  191050.39
# 3   144372.41       118671.85        383199.62      2  182901.99
# 4   142107.34        91391.77        366168.42      1  166187.94
# 5         NaN        99814.71        362861.36      3  156991.12
# 6   134615.46       147198.87        127716.82      0  156122.51
# 7   130298.13       145530.06        323876.68      1  155752.60
# 8   120542.52       148718.95        311613.29      2  152211.77
# 9   123334.88             NaN        304981.62      0  149759.96
# 10  101913.08       110594.11        229160.95      1  146121.95
# 11  100671.96        91790.61        249744.55      0  144259.40
# 12   93863.75       127320.38        249839.44      1  141585.52
# ...

# %%
from sklearn.impute import KNNImputer
a=KNNImputer()
hy=a.fit_transform(karthi)

# %%
print(hy)
# Out:
# [[1.65349200e+05 1.36897800e+05 4.71784100e+05 2.00000000e+00
#   1.92261830e+05]
#  [1.62597700e+05 1.09584336e+05 4.43898530e+05 0.00000000e+00
#   1.91792060e+05]
#  [1.53441510e+05 1.01145550e+05 4.07934540e+05 1.00000000e+00
#   1.91050390e+05]
#  [1.44372410e+05 1.18671850e+05 3.83199620e+05 2.00000000e+00
#   1.82901990e+05]
#  [1.42107340e+05 9.13917700e+04 3.66168420e+05 1.00000000e+00
#   1.66187940e+05]
#  [1.20755604e+05 9.98147100e+04 3.62861360e+05 3.00000000e+00
#   1.56991120e+05]
#  [1.34615460e+05 1.47198870e+05 1.27716820e+05 0.00000000e+00
#   1.56122510e+05]
#  [1.30298130e+05 1.45530060e+05 3.23876680e+05 1.00000000e+00
#   1.55752600e+05]
#  [1.20542520e+05 1.48718950e+05 3.11613290e+05 2.00000000e+00
#   1.52211770e+05]
#  [1.23334880e+05 1.31850682e+05 3.04981620e+05 0.00000000e+00
#   1.49759960e+05]
#  [1.01913080e+05 1.10594110e+05 2.29160950e+05 1.00000000e+00
#   1.46121950e+05]
#  [1.00671960e+05 9.17906100e+04 2.49744550e+05 0.00000000e+00
# ...

# %%
len(hy)
# Out:
# 50

# %%
len(karthi)
# Out:
# 50

# %%
tr=pd.DataFrame(hy)

# %%
tr
# Out:
#              0           1           2    3          4
# 0   165349.200  136897.800  471784.100  2.0  192261.83
# 1   162597.700  109584.336  443898.530  0.0  191792.06
# 2   153441.510  101145.550  407934.540  1.0  191050.39
# 3   144372.410  118671.850  383199.620  2.0  182901.99
# 4   142107.340   91391.770  366168.420  1.0  166187.94
# 5   120755.604   99814.710  362861.360  3.0  156991.12
# 6   134615.460  147198.870  127716.820  0.0  156122.51
# 7   130298.130  145530.060  323876.680  1.0  155752.60
# 8   120542.520  148718.950  311613.290  2.0  152211.77
# 9   123334.880  131850.682  304981.620  0.0  149759.96
# 10  101913.080  110594.110  229160.950  1.0  146121.95
# 11  100671.960   91790.610  249744.550  0.0  144259.40
# 12   93863.750  127320.380  249839.440  1.0  141585.52
# 13   91992.390  135495.070  252664.930  0.0  134307.35
# 14  119943.240  156547.420  256512.920  1.0  132602.65
# 15   90055.114  122616.840  261776.230  3.0  129917.04
# ...

# %%
x=tr.iloc[:,0:4].values
x
# Out:
# array([[1.65349200e+05, 1.36897800e+05, 4.71784100e+05, 2.00000000e+00],
#        [1.62597700e+05, 1.09584336e+05, 4.43898530e+05, 0.00000000e+00],
#        [1.53441510e+05, 1.01145550e+05, 4.07934540e+05, 1.00000000e+00],
#        [1.44372410e+05, 1.18671850e+05, 3.83199620e+05, 2.00000000e+00],
#        [1.42107340e+05, 9.13917700e+04, 3.66168420e+05, 1.00000000e+00],
#        [1.20755604e+05, 9.98147100e+04, 3.62861360e+05, 3.00000000e+00],
#        [1.34615460e+05, 1.47198870e+05, 1.27716820e+05, 0.00000000e+00],
#        [1.30298130e+05, 1.45530060e+05, 3.23876680e+05, 1.00000000e+00],
#        [1.20542520e+05, 1.48718950e+05, 3.11613290e+05, 2.00000000e+00],
#        [1.23334880e+05, 1.31850682e+05, 3.04981620e+05, 0.00000000e+00],
#        [1.01913080e+05, 1.10594110e+05, 2.29160950e+05, 1.00000000e+00],
#        [1.00671960e+05, 9.17906100e+04, 2.49744550e+05, 0.00000000e+00],
#        [9.38637500e+04, 1.27320380e+05, 2.49839440e+05, 1.00000000e+00],
# ...

# %%
y=tr.iloc[:,-1].values
y
# Out:
# array([192261.83, 191792.06, 191050.39, 182901.99, 166187.94, 156991.12,
#        156122.51, 155752.6 , 152211.77, 149759.96, 146121.95, 144259.4 ,
#        141585.52, 134307.35, 132602.65, 129917.04, 126992.93, 125370.37,
#        124266.9 , 122776.86, 118474.03, 111313.02, 110352.25, 108733.99,
#        108552.04, 107404.34, 105733.54, 105008.31, 103282.38, 101004.64,
#         99937.59,  97483.56,  97427.84,  96778.92,  96712.8 ,  96479.51,
#         90708.19,  89949.14,  81229.06,  81005.76,  78239.91,  77798.83,
#         71498.49,  69758.98,  65200.33,  64926.08,  49490.75,  42559.73,
#         35673.41,  14681.4 ])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
f=StandardScaler()
kt=f.fit_transform(x)

# %%
kt
# Out:
# array([[ 2.06049883,  0.60394846,  2.19418408,  0.77551498],
#        [ 1.9992401 , -0.40298282,  1.95699002, -1.21298497],
#        [ 1.7953889 , -0.71408497,  1.65108109, -0.21873499],
#        [ 1.59347666, -0.06796482,  1.4406864 ,  0.77551498],
#        [ 1.54304769, -1.07366537,  1.29581937, -0.21873499],
#        [ 1.06767781, -0.76314739,  1.26768959,  1.76976496],
#        [ 1.37625029,  0.98370512, -0.7324448 , -1.21298497],
#        [ 1.2801303 ,  0.92218319,  0.93608674, -0.21873499],
#        [ 1.06293376,  1.039744  ,  0.83177461,  0.77551498],
#        [ 1.12510219,  0.41788268,  0.77536577, -1.21298497],
#        [ 0.64817242, -0.36575674,  0.13043678, -0.21873499],
#        [ 0.62054043, -1.05896184,  0.30552044, -1.21298497],
#        [ 0.46896409,  0.25086971,  0.30632758, -0.21873499],
#        [ 0.42730058,  0.55223577,  0.33036113, -1.21298497],
#        [ 1.04959154,  1.3283464 ,  0.36309205, -0.21873499],
# ...

# %%
from sklearn.linear_model import LinearRegression
jk=LinearRegression()
op=jk.fit(x_train,y_train)

# %%
y_predict=op.predict(x_test)
y_predict
# Out:
# array([103143.92659347, 133557.77288889, 135272.1115133 ,  73244.27060547,
#        182518.08883042, 116416.73348676,  68868.03617389, 102159.68736231,
#        115086.68769744, 171989.16863224,  97236.35292073,  90454.3239551 ,
#        113477.0338064 ,  88796.20008377, 128539.16983633])

# %%
y_test
# Out:
# array([103282.38, 144259.4 , 146121.95,  77798.83, 191050.39, 105008.31,
#         81229.06,  97483.56, 110352.25, 166187.94,  96778.92,  96479.51,
#        105733.54,  96712.8 , 124266.9 ])

# %%
len(y_predict)
# Out:
# 15

# %%
len(y_test)
# Out:
# 15

# %%
from sklearn.metrics import r2_score
kl=r2_score(y_test,y_predict)
kl
# Out:
# 0.9403200819426735
